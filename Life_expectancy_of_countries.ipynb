# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True
import matplotlib.style
mpl.style.use('classic')
# %matplotlib inline

# %%
data = pd.read_csv('life_expectancy.csv')

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
data['Country'].nunique()
# Out:
# 193

# %%
data['Status'].nunique()
# Out:
# 2

# %%
sns.heatmap(data.isnull(),yticklabels=False,cmap='viridis',cbar=False)

# %%
d = ['Life expectancy ', 'Adult Mortality','Alcohol','Hepatitis B',' BMI ','Polio', 'Total expenditure','Diphtheria ','GDP', 
     'Population',' thinness  1-19 years', ' thinness 5-9 years','Income composition of resources', 'Schooling']

# %%
df = data.groupby(["Country",'Year']).mean()
df
# Out:
#                   Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# Country     Year
# Afghanistan 2000              54.8            321.0             88     0.01
#             2001              55.3            316.0             88     0.01
#             2002              56.2              3.0             88     0.01
#             2003              56.7            295.0             87     0.01
#             2004              57.0            293.0             87     0.02
#             2005              57.3            291.0             85     0.02
#             2006              57.3            295.0             84     0.03
#             2007              57.5            295.0             82     0.02
#             2008              58.1            287.0             80     0.03
#             2009              58.6            281.0             77     0.01
#             2010              58.8            279.0             74     0.01
# ...

# %%
df.xs(['Afghanistan',2000])
# Out:
# Life expectancy                        54.80000
# Adult Mortality                       321.00000
# infant deaths                          88.00000
# Alcohol                                 0.01000
# percentage expenditure                 10.42496
# Hepatitis B                            62.00000
# Measles                              6532.00000
#  BMI                                   12.20000
# under-five deaths                     122.00000
# Polio                                  24.00000
# Total expenditure                       8.20000
# Diphtheria                             24.00000
#  HIV/AIDS                               0.10000
# GDP                                   114.56000
# Population                         293756.00000
#  thinness  1-19 years                   2.30000
#  thinness 5-9 years                     2.50000
# Income composition of resources         0.33800
# Schooling                               5.50000
# Name: (Afghanistan, 2000), dtype: float64

# %%
status = pd.get_dummies(data['Status'],drop_first=True)

# %%
data = pd.concat([data,status],axis=1)

# %%
data.drop(columns=['Status'],axis=1,inplace=True)

# %%
data
# Out:
#           Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0     Afghanistan  2015              65.0            263.0             62
# 1     Afghanistan  2014              59.9            271.0             64
# 2     Afghanistan  2013              59.9            268.0             66
# 3     Afghanistan  2012              59.5            272.0             69
# 4     Afghanistan  2011              59.2            275.0             71
# 5     Afghanistan  2010              58.8            279.0             74
# 6     Afghanistan  2009              58.6            281.0             77
# 7     Afghanistan  2008              58.1            287.0             80
# 8     Afghanistan  2007              57.5            295.0             82
# 9     Afghanistan  2006              57.3            295.0             84
# 10    Afghanistan  2005              57.3            291.0             85
# 11    Afghanistan  2004              57.0            293.0             87
# ...

# %%
c = data.columns
c
# Out:
# Index(['Country', 'Year', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Developing'],
#       dtype='object')

# %%
d = ['Life expectancy ', 'Adult Mortality','Alcohol','Hepatitis B',' BMI ','Polio', 'Total expenditure','Diphtheria ','GDP', 
     'Population',' thinness  1-19 years', ' thinness 5-9 years','Income composition of resources', 'Schooling']

# %%
df.loc['Afghanistan'].loc[2000]['Alcohol']
# Out:
# 0.01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
#  HIV/AIDS                          2938 non-null float64
# ...

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
#  HIV/AIDS                          2938 non-null float64
# ...

# %%
d = ['Life expectancy ', 'Adult Mortality','Alcohol','Hepatitis B',' BMI ','Polio', 'Total expenditure','Diphtheria ','GDP', 
     'Population',' thinness  1-19 years', ' thinness 5-9 years','Income composition of resources', 'Schooling']

# %%
d
# Out:
# ['Life expectancy ',
#  'Adult Mortality',
#  'Alcohol',
#  'Hepatitis B',
#  ' BMI ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %%
df
# Out:
#                   Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# Country     Year
# Afghanistan 2000              54.8            321.0             88     0.01
#             2001              55.3            316.0             88     0.01
#             2002              56.2              3.0             88     0.01
#             2003              56.7            295.0             87     0.01
#             2004              57.0            293.0             87     0.02
#             2005              57.3            291.0             85     0.02
#             2006              57.3            295.0             84     0.03
#             2007              57.5            295.0             82     0.02
#             2008              58.1            287.0             80     0.03
#             2009              58.6            281.0             77     0.01
#             2010              58.8            279.0             74     0.01
# ...

# %%
data
# Out:
#           Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0     Afghanistan  2015              65.0            263.0             62
# 1     Afghanistan  2014              59.9            271.0             64
# 2     Afghanistan  2013              59.9            268.0             66
# 3     Afghanistan  2012              59.5            272.0             69
# 4     Afghanistan  2011              59.2            275.0             71
# 5     Afghanistan  2010              58.8            279.0             74
# 6     Afghanistan  2009              58.6            281.0             77
# 7     Afghanistan  2008              58.1            287.0             80
# 8     Afghanistan  2007              57.5            295.0             82
# 9     Afghanistan  2006              57.3            295.0             84
# 10    Afghanistan  2005              57.3            291.0             85
# 11    Afghanistan  2004              57.0            293.0             87
# ...

# %%
for i in range(0,2938) :
    if (pd.isnull(data['Life expectancy '].iloc[i])) :
        #print(data['Life expectancy '].iloc[i])
        if pd.isnull(df.xs([data['Country'].iloc[i],data['Year'].iloc[i]])['Life expectancy ']) :
            data['Life expectancy '].iloc[i] = data['Life expectancy '].mean()
        else :
            data['Life expectancy '].iloc[i] = df.xs([data['Country'].iloc[i],data['Year'].iloc[i]])['Life expectancy ']
# Out:
# C:\Users\DELL\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.xs([data['Country'].iloc[i],data['Year'].iloc[i]])['Life expectancy ']
# Out:
# 46.0

# %%
data['Life expectancy '].mean()
# Out:
# 69.22493169398906

# %%
data[data['Life expectancy '].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Life expectancy , Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles ,  BMI , under-five deaths , Polio, Total expenditure, Diphtheria ,  HIV/AIDS, GDP, Population,  thinness  1-19 years,  thinness 5-9 years, Income composition of resources, Schooling, Developing]
# Index: []
#
# [0 rows x 22 columns]

# %%
d.pop(0)
# Out:
# 'Life expectancy '

# %%
d
# Out:
# ['Adult Mortality',
#  'Alcohol',
#  'Hepatitis B',
#  ' BMI ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %%
for l in d :
    for i in range(0,2938) :
        if (pd.isnull(data[l].iloc[i])) :
            if pd.isnull(df.xs([data['Country'].iloc[i],data['Year'].iloc[i]])[l]) :
                data[l].iloc[i] = data[l].mean()
            else :
                data[l].iloc[i] = df.xs([data['Country'].iloc[i],data['Year'].iloc[i]])[l]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Life expectancy                    2938 non-null float64
# Adult Mortality                    2938 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2938 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2938 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2938 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2938 non-null float64
# Total expenditure                  2938 non-null float64
# Diphtheria                         2938 non-null float64
#  HIV/AIDS                          2938 non-null float64
# ...

# %%
data.drop(['Country','Year'],inplace=True,axis=1)

# %%
data
# Out:
#       Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# 0                 65.0            263.0             62  0.010000
# 1                 59.9            271.0             64  0.010000
# 2                 59.9            268.0             66  0.010000
# 3                 59.5            272.0             69  0.010000
# 4                 59.2            275.0             71  0.010000
# 5                 58.8            279.0             74  0.010000
# 6                 58.6            281.0             77  0.010000
# 7                 58.1            287.0             80  0.030000
# 8                 57.5            295.0             82  0.020000
# 9                 57.3            295.0             84  0.030000
# 10                57.3            291.0             85  0.020000
# 11                57.0            293.0             87  0.020000
# 12                56.7            295.0             87  0.010000
# ...

# %%
X = data.drop(['Life expectancy '],axis=1)
y = data['Life expectancy ']

# %%
X
# Out:
#       Adult Mortality  infant deaths   Alcohol  percentage expenditure  \
# 0               263.0             62  0.010000               71.279624
# 1               271.0             64  0.010000               73.523582
# 2               268.0             66  0.010000               73.219243
# 3               272.0             69  0.010000               78.184215
# 4               275.0             71  0.010000                7.097109
# 5               279.0             74  0.010000               79.679367
# 6               281.0             77  0.010000               56.762217
# 7               287.0             80  0.030000               25.873925
# 8               295.0             82  0.020000               10.910156
# 9               295.0             84  0.030000               17.171518
# 10              291.0             85  0.020000                1.388648
# 11              293.0             87  0.020000               15.296066
# ...

# %%
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
# 5       58.8
# 6       58.6
# 7       58.1
# 8       57.5
# 9       57.3
# 10      57.3
# 11      57.0
# 12      56.7
# 13      56.2
# 14      55.3
# 15      54.8
# 16      77.8
# 17      77.5
# 18      77.2
# 19      76.9
# 20      76.6
# 21      76.2
# 22      76.1
# 23      75.3
# 24      75.9
# 25      74.2
# 26      73.5
# 27      73.0
# 28      72.8
# 29      73.3
#         ...
# 2908    63.0
# 2909    59.2
# 2910    58.2
# 2911    58.0
# 2912    57.4
# 2913    55.7
# 2914    52.6
# 2915    58.0
# 2916    49.3
# 2917    47.9
# 2918    46.4
# 2919    45.5
# 2920    44.6
# 2921    43.8
# 2922    67.0
# 2923    59.2
# 2924    58.0
# 2925    56.6
# 2926    54.9
# 2927    52.4
# 2928    50.0
# 2929    48.2
# 2930    46.6
# 2931    45.4
# 2932    44.6
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# print the intercept
print(lm.intercept_)
# Out:
# 56.23669903282051

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                   Coefficient
# Adult Mortality                 -1.998483e-02
# infant deaths                    1.140752e-01
# Alcohol                          6.652688e-02
# percentage expenditure           7.201671e-05
# Hepatitis B                     -2.151292e-02
# Measles                         -2.316143e-05
#  BMI                             4.021824e-02
# under-five deaths               -8.720147e-02
# Polio                            3.685127e-02
# Total expenditure                3.562569e-02
# Diphtheria                       4.023089e-02
#  HIV/AIDS                       -4.304300e-01
# GDP                              4.285965e-05
# Population                       1.843277e-09
#  thinness  1-19 years           -1.187939e-01
#  thinness 5-9 years              4.146693e-02
# Income composition of resources  5.387845e+00
# Schooling                        6.952855e-01
# Developing                      -1.465892e+00

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.031977628993006
# MSE: 16.28362160717254
# RMSE: 4.035296966416789
